# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import requests
import io
import openpyxl  # You may need to install this: pip install openpyxl


# URL of the raw file
url = "https://raw.github.com/MyungKyuYi/AI-class/main/combined_dataset-1.xlsx"

try:
    # Method 1: Direct reading (may work for smaller files)
    df = pd.read_excel(url, engine='openpyxl')
    print("Method 1 succeeded")
except Exception as e:
    print(f"Direct reading failed: {e}")
    
    try:
        # Method 2: Download the content first, then read
        response = requests.get(url)
        if response.status_code == 200:
            # Create a file-like object from the response content
            excel_data = io.BytesIO(response.content)
            # Read the Excel file from the file-like object
            df = pd.read_excel(excel_data, engine='openpyxl')
            print("Method 2 succeeded")
        else:
            print(f"Failed to download the file. Status code: {response.status_code}")
    except Exception as e:
        print(f"Method 2 failed: {e}")

# If we got here successfully, show the data
print("\n데이터프레임의 처음 5행:")
print(df.head())
print("\n열 이름:")
print(df.columns)
# Out:
# Method 1 succeeded
#
# 데이터프레임의 처음 5행:
#    Num.  subject_ID Sex(M/F)  Age(year)  Height(cm)  Weight(kg)  \
# 0     1           2   Female         45         152          63
# 1     1           2   Female         45         152          63
# 2     1           2   Female         45         152          63
# 3     2           3   Female         50         157          50
# 4     2           3   Female         50         157          50
#
#    Systolic Blood Pressure(mmHg)  Diastolic Blood Pressure(mmHg)  \
# 0                            161                              89
# 1                            161                              89
# 2                            161                              89
# 3                            160                              93
# 4                            160                              93
#
#    Heart Rate(b/m)  BMI(kg/m^2)  ...  2091  2092  2093  2094  2095  2096  \
# ...
